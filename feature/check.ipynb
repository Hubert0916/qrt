# %%
import polars as pl
import numpy as np

df = pl.read_csv("/Users/coconut/qrt/data/esg_tfidf_with_return_cleaned.csv")

# %%
import matplotlib.pyplot as plt

plt.hist(df["報酬率"], bins=100, range=(-1, 1))
plt.xlabel("Return")
plt.ylabel("Frequency")
plt.title("Return Distribution")
plt.show()
